# %%
import pandas as pd 
import numpy as np

# %%
csv_file='../results/tuned_results/17_06_2022_19:17:24/grid_search.csv'

# %%
df=pd.read_csv(csv_file, index_col='Unnamed: 0')

# %%
df[df['model']=='listened_to_artist'].describe()
# Out:
#             RMSE        MAE     nrows  num_layers  sample_edge_rate  \
# count  23.000000  23.000000      23.0        23.0      2.300000e+01
# mean    0.335209   0.183365  100000.0         2.0      1.000000e-02
# std     0.046899   0.049641       0.0         0.0      3.547422e-18
# min     0.237000   0.101800  100000.0         2.0      1.000000e-02
# 25%     0.325450   0.158700  100000.0         2.0      1.000000e-02
# 50%     0.360700   0.193400  100000.0         2.0      1.000000e-02
# 75%     0.368100   0.209200  100000.0         2.0      1.000000e-02
# max     0.374200   0.279700  100000.0         2.0      1.000000e-02
#
#        batch_size  num_neg_samples  node_min_neighbors  num_workers  \
# count        23.0             23.0                23.0         23.0
# mean        512.0              5.0                 5.0          4.0
# std           0.0              0.0                 0.0          0.0
# min         512.0              5.0                 5.0          4.0
# ...

# %%
for k,v in df[df['RMSE']==0.237000].items():
    print(f'{k}: ', v.item())
# Out:
# model:  listened_to_artist
# time:  17_06_2022_14:59:58
# path_to_loss_img:  results/lfm1b/17_06_2022_14:59:58/listened_to_artist/listened_to_album_loss_plot.png
# path_to_mae_img:  results/lfm1b/17_06_2022_14:59:58/listened_to_artist/listened_to_album_mae_plot.png
# path_to_rmse_img:  results/lfm1b/17_06_2022_14:59:58/listened_to_artist/listened_to_album_rmse_plot.png
# path_to_pkl:  results/lfm1b/17_06_2022_14:59:58/listened_to_artist/listened_to_album.pkl
# RMSE:  0.237
# MAE:  0.1048
# nrows:  100000
# num_layers:  2
# sample_edge_rate:  0.01
# batch_size:  512
# num_neg_samples:  5
# node_min_neighbors:  5
# shuffle:  True
# drop_last:  False
# num_workers:  4
# hidden_dim:  32
# rel_input_dim:  12
# rel_hidden_dim:  32
# num_heads:  8
# dropout:  0.05
# residual:  False
# norm:  True
# opt:  adam
# learing_rate:  0.001
# weight_decay:  0.0
# epochs:  200
# device:  cuda
# patience:  50
# overwrite_raw:  False
# overwrite_preprocessed:  False
# overwrite_processed:  False
